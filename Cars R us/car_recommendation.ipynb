# %%
import os
import pandas as pd
direct = "dataset"
names = os.listdir(direct)
for i in names:
    print(i)
    display(pd.read_csv(f"dataset/{i}").head())
# autoscout24-germany-dataset.csv - mileage, make,model,fuel,gear, pice, hp,year
# carsclean.csv- car_maker=> make, model, year,condition,kilometers,transmission => gear, fuel, colour, price, pay_method
# Car_Prices_Poland_Kaggle.csv -  mark => mark, model, year, mileage, fuel, price
# Electric cars.csv - BEV average price (USD) => price, Mileage (Km) => mileage, Average price of new car, Lithium Ion Battery Price,Average price of new car
# Nigerian_Car_Prices.csv - Make => make, Year of manufacture => year,Mileage => mileage, Transmission= > gear, Price => price(Nigerian => GBP)
# train.csv => etc.
# Out:
# autoscout24-germany-dataset.csv
#    mileage        make   model      fuel    gear offerType  price     hp  year
# 0   235000         BMW     316    Diesel  Manual      Used   6800  116.0  2011
# 1    92800  Volkswagen    Golf  Gasoline  Manual      Used   6877  122.0  2011
# 2   149300        SEAT    Exeo  Gasoline  Manual      Used   6900  160.0  2011
# 3    96200     Renault  Megane  Gasoline  Manual      Used   6950  110.0  2011
# 4   156000     Peugeot     308  Gasoline  Manual      Used   6950  156.0  2011
# carsclean.csv
#         city car_maker     model  year condition  kilometers transmission  \
# 0  Al Riyadh    Toyota      Rush  2019      Used     14999.5    Automatic
# 1  Al Riyadh       Kia  Carnival  2006      Used         0.0    Automatic
# 2  Al Riyadh    Toyota     Camry  2014      Used     24999.5    Automatic
# 3  Al Riyadh      Ford    Fusion  2010      Used    200000.0    Automatic
# 4  Al Riyadh      Ford    Taurus  2018      Used      5000.0    Automatic
#
# ...
